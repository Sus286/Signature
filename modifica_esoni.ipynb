# %%
import pandas as pd

# Specifica il percorso del file TSV
file_path = "/content/drive/MyDrive/esoni.tsv"

# Carica il file TSV in un DataFrame
esoni_copy = pd.read_csv(file_path, sep='\t')

# %%
esoni_copy
# Out:
#                         chrom  exonStarts  exonEnds      name2
# 0                        chr1    66999043  66999090      SGIP1
# 1                        chr1    66999928  67000051      SGIP1
# 2                        chr1    67091529  67091593      SGIP1
# 3                        chr1    67098752  67098777      SGIP1
# 4                        chr1    67101626  67101698      SGIP1
# ...                       ...         ...       ...        ...
# 972051   chr7_gl000195_random       48954     49119  LOC389831
# 972052   chr7_gl000195_random       86517     86735  LOC389831
# 972053   chr7_gl000195_random       42937     44923  LOC389831
# 972054   chr7_gl000195_random       86517     86735  LOC389831
# 972055  chr17_gl000205_random      116622    119732   MGC70870
#
# [972056 rows x 4 columns]

# %%
esoni_noduplicati=esoni_copy.drop_duplicates()

# %%
ESONI=esoni_noduplicati.copy()

# %%
esoni_noduplicati['exonEnds']=esoni_noduplicati['exonEnds']+1
esoni_noduplicati['exonStarts'] = esoni_noduplicati.apply(lambda row: row['exonStarts'] - 1 if row['exonStarts']!= 0 else row['exonStarts'], axis=1)
# Out:
# <ipython-input-14-b9c783f1de09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   esoni_noduplicati['exonEnds']=esoni_noduplicati['exonEnds']+1
# <ipython-input-14-b9c783f1de09>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   esoni_noduplicati['exonStarts'] = esoni_noduplicati.apply(lambda row: row['exonStarts'] - 1 if row['exonStarts']!= 0 else row['exonStarts'], axis=1)

# %%
esoni_noduplicati
# Out:
#                         chrom  exonStarts  exonEnds      name2
# 0                        chr1    66999042  66999091      SGIP1
# 1                        chr1    66999927  67000052      SGIP1
# 2                        chr1    67091528  67091594      SGIP1
# 3                        chr1    67098751  67098778      SGIP1
# 4                        chr1    67101625  67101699      SGIP1
# ...                       ...         ...       ...        ...
# 972040   chr7_gl000195_random       48953     49120  LOC389831
# 972041   chr7_gl000195_random       74119     74181  LOC389831
# 972042   chr7_gl000195_random       86516     86736  LOC389831
# 972043   chr7_gl000195_random       42936     44924  LOC389831
# 972055  chr17_gl000205_random      116621    119733   MGC70870
#
# [300378 rows x 4 columns]

# %%
ESONI
# Out:
#                         chrom  exonStarts  exonEnds      name2
# 0                        chr1    66999043  66999090      SGIP1
# 1                        chr1    66999928  67000051      SGIP1
# 2                        chr1    67091529  67091593      SGIP1
# 3                        chr1    67098752  67098777      SGIP1
# 4                        chr1    67101626  67101698      SGIP1
# ...                       ...         ...       ...        ...
# 972040   chr7_gl000195_random       48954     49119  LOC389831
# 972041   chr7_gl000195_random       74120     74180  LOC389831
# 972042   chr7_gl000195_random       86517     86735  LOC389831
# 972043   chr7_gl000195_random       42937     44923  LOC389831
# 972055  chr17_gl000205_random      116622    119732   MGC70870
#
# [300378 rows x 4 columns]

# %%
# Specifica il percorso del file in cui desideri salvare il DataFrame in formato TSV
output_file_path = "/content/drive/MyDrive/esoni_noduplicati.tsv"

# Salva il DataFrame come file TSV
esoni_noduplicati.to_csv(output_file_path, sep='\t', index=False)

# %%
# Specifica il percorso del file in cui desideri salvare il DataFrame in formato TSV
output_file_path = "/content/drive/MyDrive/ESONI.tsv"

# Salva il DataFrame come file TSV
ESONI.to_csv(output_file_path, sep='\t', index=False)

# %%
esoni_copy['exonEnds']=esoni_copy['exonEnds']+1
esoni_copy['exonStarts'] = esoni_copy.apply(lambda row: row['exonStarts'] - 1 if row.name != 0 else row['exonStarts'], axis=1)

# %%
esoni_copy
# Out:
#                         chrom  exonStarts  exonEnds      name2
# 0                        chr1    66999043  66999091      SGIP1
# 1                        chr1    66999927  67000052      SGIP1
# 2                        chr1    67091528  67091594      SGIP1
# 3                        chr1    67098751  67098778      SGIP1
# 4                        chr1    67101625  67101699      SGIP1
# ...                       ...         ...       ...        ...
# 972051   chr7_gl000195_random       48953     49120  LOC389831
# 972052   chr7_gl000195_random       86516     86736  LOC389831
# 972053   chr7_gl000195_random       42936     44924  LOC389831
# 972054   chr7_gl000195_random       86516     86736  LOC389831
# 972055  chr17_gl000205_random      116621    119733   MGC70870
#
# [972056 rows x 4 columns]

# %%
#import numpy as np
#np.shape(esoni_copy)[0]
# Out:
# 972056

# %%
#import pandas as pd

# Crea una copia del DataFrame esoni_copy
#esoni_copy = esoni_copy.copy()

# Arrotonda le posizioni iniziali e finali ai multipli di tre più vicini
#esoni_copy['exonStarts'] = esoni_copy['exonStarts'].apply(lambda x: (x + 2) // 3 * 3 if x % 3 != 0 else x)
#esoni_copy['exonEnds'] = esoni_copy['exonEnds'].apply(lambda x: (x // 3) * 3 if x % 3 != 0 else x)

# %%
#esoni_copy
# Out:
#                         chrom  exonStarts  exonEnds      name2
# 0                        chr1    66999045  66999090      SGIP1
# 1                        chr1    66999930  67000050      SGIP1
# 2                        chr1    67091529  67091592      SGIP1
# 3                        chr1    67098753  67098777      SGIP1
# 4                        chr1    67101627  67101696      SGIP1
# ...                       ...         ...       ...        ...
# 972051   chr7_gl000195_random       48954     49119  LOC389831
# 972052   chr7_gl000195_random       86517     86733  LOC389831
# 972053   chr7_gl000195_random       42939     44922  LOC389831
# 972054   chr7_gl000195_random       86517     86733  LOC389831
# 972055  chr17_gl000205_random      116622    119730   MGC70870
#
# [972056 rows x 4 columns]

# %%
#diff=esoni_copy['exonEnds']-esoni_copy['exonStarts']

# %%
#diff[diff%3!=0] #tutti multiplti di tre top
# Out:
# Series([], dtype: int64)

# %%
# Specifica il percorso del file in cui desideri salvare il DataFrame in formato TSV
output_file_path = "/content/drive/MyDrive/esoni_modificati.tsv"

# Salva il DataFrame come file TSV
esoni_copy.to_csv(output_file_path, sep='\t', index=False)
